# %%
import pymc as pm
import pandas as pd
import numpy as np
import dendropy
import monkey_model
import matrix_functions as mf
# Out:
# /home/walrus/.virtualenvs/py/local/lib/python2.7/site-packages/pytz/__init__.py:35: UserWarning: Module multiprocessing was already imported from /usr/lib/python2.7/multiprocessing/__init__.pyc, but /home/walrus/.virtualenvs/py/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %%
reload(monkey_model)
# Out:
# <module 'monkey_model' from 'monkey_model.pyc'>

# %%
M = pm.MCMC(monkey_model, db='pickle', dbname='NWM.pickle')

# %%
M.sample(iter=5000, burn=4000, thin=10)
M.db.close()
# Out:
# [****************100%******************]  5000 of 5000 complete

# %%
x= [(k,v.trace[-1]) for k,v in M.var_factors.items() ]
sorted(x, key=lambda y: y[1])
# Out:
# [('Saguinus_fuscicollis__fuscicollis_fuscus', 0.0025180588119710712),
#  ('Callithrix_penicillata__penicillata_penicillata__F', 0.0029960176448827758),
#  ('Callithrix_geoffroyi__geoffroyi_geoffroyi__M', 0.0031995074693295989),
#  ('Callithrix_jacchus__jacchus_jacchus__F', 0.0043413922580888796),
#  ('Callithrix_penicillata__penicillata_penicillata__M', 0.004948502902859188),
#  ('Saguinus_fuscicollis__fuscicollis_weddelli', 0.0053542110303066593),
#  ('Callimico_goeldii__goeldii_goeldii__F', 0.0062476964044698227),
#  ('Callithrix_jacchus__jacchus_jacchus__M', 0.0062590135045854089),
#  ('Saguinus_midas__midas_umbratus', 0.0064548844540085783),
#  ('Callithrix_geoffroyi__geoffroyi_geoffroyi__F', 0.0065750920184419158),
#  ('Saguinus_mystax__mystax_mystax__M', 0.0083118600392163011),
#  ('Saguinus mystax', 0.0087278475715963488),
#  ('Callithrix_pygmaea__pygmaea_susan1', 0.0096670591637078515),
#  ('Callithrix_humeralifera__humeralifera_humeralifera__M',
#   0.011699756986079194),
#  ('Callithrix_argentata__argentata_argentata__M', 0.013558013853455817),
#  ('Saguinus_midas__midas_niger__F', 0.013973033177256575),
#  ('Callithrix_humeralifera__humeralifera_humeralifera__F',
#   0.016420705996496518),
#  ('Callithrix_pygmaea__pygmaea_jim__F', 0.016921728728895621),
#  ('Callithrix_pygmaea__pygmaea_susan1__F', 0.017016051624594172),
#  ('Saguinus_midas__midas_umbratus__M', 0.017625437584057879),
#  ('Saguinus_midas__midas_umbratus__F', 0.017775912540787805),
#  ('Aotus_lemurinus__lemurinus_lemurinus__M', 0.018499127074373192),
#  ('Saguinus_mystax__mystax_mystax', 0.018696344321101212),
#  ('Callithrix_pygmaea__pygmaea_jim__M', 0.019046439300964484),
#  ('Aotus_azarai_boliviensis__azarai_boliviensis__F', 0.021116535615200785),
#  ('Saguinus_midas__midas_midas', 0.02149056387573188),
#  ('Callithrix_kuhli__kuhli_kuhli__F', 0.021942871216659832),
#  ('Callithrix_pygmaea__pygmaea_gabriel__F', 0.024339363057956101),
#  ('Aotus_lemurinus__lemurinus_lemurinus__F', 0.025444097338657618),
#  ('Callithrix_pygmaea__pygmaea_susan2', 0.44563322878694611),
#  ('4', 0.52603111390329216),
#  ('11', 0.6058242880579362),
#  ('26', 0.61646912253719555),
#  ('3', 0.66620643347281128),
#  ('2', 0.74600982539278116),
#  ('7', 0.74825337548811954),
#  ('25', 0.77453757331009443),
#  ('27', 1.0196772713150297),
#  ('12', 1.6960424413000998),
#  ('8', 1.7053029290232373),
#  ('23', 1.7776080154724454),
#  ('10', 2.2872257555214603),
#  ('Saguinus_fuscicollis__fuscicollis_lagonotus__M', 2.6060403497983264),
#  ('15', 3.6851668066183989),
#  ('9', 5.7714222463195792),
#  ('6', 49.06157819362798),
#  ('1', 105.03524106115124)]

# %%
d = {'a': 1}
d.items()
# Out:
# [('a', 1)]

# %%
pop_size = 100
pops = {}

for species in monkey_model.data_list:
    species_name = str(species).replace('data_', '')
    thetas = M.get_node('theta_{}'.format(species_name)).trace()
    sigmas = M.get_node('sigma_{}'.format(species_name)).trace()
    
    params = zip(thetas, sigmas)
        
    pops[species_name] = []
    for p in params:

        pops[species_name].append(np.random.multivariate_normal(p[0], p[1], pop_size))
        
    pops[species_name] = np.array(pops[species_name])

# %%
pops['Callithrix_pygmaea__pygmaea_gabriel__F'][0]
# Out:
# array([[  3.42810685,   6.21958282,  12.18897678, ...,  19.17746481,
#           9.26869802,   6.29869389],
#        [  3.57967322,   5.84832736,  11.58546845, ...,  20.11667685,
#           9.56670353,   5.60728127],
#        [  3.488742  ,   5.80195415,  12.2437338 , ...,  18.20168561,
#           9.64144857,   5.7899238 ],
#        ...,
#        [  3.75000694,   6.55214535,  11.54066881, ...,  16.6744061 ,
#           9.13973625,   6.41191342],
#        [  3.77630521,   6.27066924,  12.55693897, ...,  19.02263854,
#           9.37819277,   6.1851938 ],
#        [  3.49614148,   5.67211685,  10.85510768, ...,  18.34103857,
#           9.52180344,   5.11576028]])

# %%
stats = {}

for species in monkey_model.data_list:
    species_name = str(species).replace('data_', '')
    print species_name
    stats[species_name] = {}
    stats[species_name]['mean'] = np.array([r.mean(0) for r in pops[species_name]])
    stats[species_name]['var'] = np.array([r.var(0) for r in pops[species_name]])
    stats[species_name]['min'] = np.array([r.min(0) for r in pops[species_name]])
    stats[species_name]['max'] = np.array([r.max(0) for r in pops[species_name]])
# Out:
# Aotus_azarai_boliviensis__azarai_boliviensis__M
# Aotus_azarai_boliviensis__azarai_boliviensis__F
# Aotus_nigriceps__nigriceps_nigriceps__M
# Aotus_nigriceps__nigriceps_nigriceps__F
# Aotus_lemurinus__lemurinus_lemurinus__M
# Aotus_lemurinus__lemurinus_lemurinus__F
# Callimico_goeldii__goeldii_goeldii__M
# Callimico_goeldii__goeldii_goeldii__F
# Callithrix_argentata__argentata_argentata__M
# Callithrix_argentata__argentata_argentata__F
# Callithrix_humeralifera__humeralifera_humeralifera__M
# Callithrix_humeralifera__humeralifera_humeralifera__F
# Callithrix_pygmaea__pygmaea_susan1__M
# Callithrix_pygmaea__pygmaea_susan1__F
# Callithrix_pygmaea__pygmaea_susan2__M
# Callithrix_pygmaea__pygmaea_susan2__F
# Callithrix_pygmaea__pygmaea_jim__M
# Callithrix_pygmaea__pygmaea_jim__F
# Callithrix_pygmaea__pygmaea_gabriel__M
# Callithrix_pygmaea__pygmaea_gabriel__F
# Callithrix_geoffroyi__geoffroyi_geoffroyi__M
# Callithrix_geoffroyi__geoffroyi_geoffroyi__F
# Callithrix_jacchus__jacchus_jacchus__M
# Callithrix_jacchus__jacchus_jacchus__F
# Callithrix_kuhli__kuhli_kuhli__M
# Callithrix_kuhli__kuhli_kuhli__F
# Callithrix_penicillata__penicillata_penicillata__M
# Callithrix_penicillata__penicillata_penicillata__F
# Leontopithecus_rosalia__rosalia_rosalia__M
# Leontopithecus_rosalia__rosalia_rosalia__F
# Saguinus_midas__midas_umbratus__M
# Saguinus_midas__midas_umbratus__F
# Saguinus_midas__midas_midas__M
# Saguinus_midas__midas_midas__F
# Saguinus_midas__midas_niger__M
# Saguinus_midas__midas_niger__F
# Saguinus_mystax__mystax_pileatus__M
# Saguinus_mystax__mystax_pileatus__F
# Saguinus_mystax__mystax_mystax__M
# Saguinus_mystax__mystax_mystax__F
# Saguinus_fuscicollis__fuscicollis_fuscus__M
# Saguinus_fuscicollis__fuscicollis_fuscus__F
# Saguinus_fuscicollis__fuscicollis_weddelli__M
# Saguinus_fuscicollis__fuscicollis_weddelli__F
# Saguinus_fuscicollis__fuscicollis_lagonotus__M
# Saguinus_fuscicollis__fuscicollis_lagonotus__F
# Saguinus_fuscicollis__fuscicollis_fuscicollis__M
# Saguinus_fuscicollis__fuscicollis_fuscicollis__F

# %%
plot_mean_hists('Saguinus_midas__midas_niger__M', stats, 2)

# %%
from matplotlib.pyplot import *

def plot_mean_hists(species, stats, r):
    pop_m = stats[species]['mean']

    for ti in xrange(0, pop_m.shape[1]):
        figure(r*pop_m.shape[1] + ti)
        hist(pop_m[:,ti])
        orig_m = M.get_node('data_' + species).value.mean(0)[ti]
        axvline(orig_m, color='r', linestyle='dashed', linewidth=2)    
        xlabel(species)
        
def plot_mean(species, stats, r):
    pop_m = stats[species]['mean']

    for ti in xrange(0, pop_m.shape[1]):
        figure(r*pop_m.shape[1] + ti)
        plot(pop_m[:,ti])
        orig_m = M.get_node('data_' + species).value.mean(0)[ti]
        axhline(orig_m, color='r', linestyle='dashed', linewidth=2)
        
def plot_size(species, stats, r):
    pop_m = stats[species]['mean']

    for ti in xrange(0, pop_m.shape[1]):
        figure(r*pop_m.shape[1] + ti)
        plot(pop_m[:,ti])
        orig_m = len(M.get_node('data_' + species).value)
        axhline(orig_m, color='r', linestyle='dashed', linewidth=2)

# %%
len(M.get_node('data_' + 'Saguinus_midas__midas_niger__M').value)
# Out:
# 10

# %%
root = monkey_model.t.seed_node
tree_idx = {str(root): 0}
bayes_means = {str(root): M.theta[tree_idx[str(root)]].trace[:].mean(0)}
bayes_matrices = {str(root): M.sigma[tree_idx[str(root)]].trace[:].mean(0)}
ML_matrices = monkey_model.node_matrices
ML_means = monkey_model.node_means

i = 1
for n in monkey_model.t.nodes()[1:]:
    tree_idx[str(n)] = i
    bayes_means[str(n)] = M.theta[tree_idx[str(n)]].trace[:].mean(0)
    bayes_matrices[str(n)] = M.sigma[tree_idx[str(n)]].trace[:].mean(0)
    i = i + 1

is_named = lambda node: ((node.taxon is not None) or (node.label is not None))

get_node_name = lambda n: n.label or n.taxon or None

for n in monkey_model.t.nodes(filter_fn=(is_named)):
    name = get_node_name(n)
    print str(name), str(n)
    
    print "RS = ", mf.random_skewers(ML_matrices[str(n)], bayes_matrices[str(n)])                                              
    print ML_means[str(n)] - bayes_means[str(n)]
# Out:
# Aotus d73295888
# RS =
# 0.998811618368
# [ 0.0213674   0.14309203  0.27741886  0.50558824  0.8274357   0.37705912
#   0.22669421  0.27522566  0.46031347  0.38509997 -0.00702831  0.88106568
#   0.00453295 -0.19959268  0.98973872 -0.16241551 -0.16469906 -0.48550559
#  -0.06294684 -0.47859255 -0.2165117   0.41659015  0.54190079  0.1621218
#  -0.30159274 -0.07690677 -0.29354454  0.63090613  0.21131809  0.24385901
#  -0.12278221 -0.07935024  0.16469948 -0.30206087  0.9636645  -0.54945025
#  -0.03521223 -0.27680695  0.48111649]
# Aotus azarai boliviensis d73296144
# RS =
# 0.999181977784
# [ 0.00565459  0.03921428  0.08827054 -0.11630727  0.14359287  0.13495169
#   0.06645893  0.169699    0.10016501 -0.1073705   0.0072636   0.38873258
#   0.39054702  0.11284104  0.09267541  0.09899486 -0.05267307  0.04204733
#  -0.1686172   0.04952459 -0.35143666  0.05808697  0.00625742  0.12156602
#  -0.04968001 -0.0039678  -0.03146633  0.17643795  0.05803978 -0.18726559
#  -0.13356584 -0.18991032 -0.25894601  0.23921469  0.29373174  0.22468914
#   0.12135373  0.01372539 -0.06120485]
# Aotus nigriceps d73296400
# RS =
# 0.999336281035
# [ 0.07741005 -0.1211957   0.09951674 -0.19949019  0.02937086 -0.0408085
#   0.10018551 -0.06213474  0.14657601 -0.17036972  0.06079616  0.12917923
#  -0.16775215 -0.14657583  0.15046121  0.34647481  0.06693972  0.07021256
#   0.0847708   0.05091864  0.05242822 -0.12984842  0.34199241 -0.09687887
#   0.04619372  0.06509533 -0.0881104   0.00268995 -0.05338884  0.07184438
#  -0.17825252  0.00718248 -0.06245857  0.04508109  0.15357107 -0.05396416
#  -0.18333227 -0.35746879  0.11351163]
# Aotus lemurinus d73296656
# RS =
# 0.999995764945
# [ 0.01889913  0.0053828   0.10129317 -0.01838101  0.06467512 -0.05359559
#   0.02680093  0.12447611  0.03825904 -0.01439338 -0.07931449 -0.00206837
#   0.00810835 -0.08012602  0.09114888  0.14502374  0.01260553 -0.06364666
#   0.17966722  0.03311628  0.13047057 -0.0181632   0.22291332  0.08300282
#  -0.0441816  -0.09383171 -0.1606323  -0.15009222  0.00184094  0.06410382
#  -0.04627477 -0.05903372  0.03590161 -0.01028218  0.02747781  0.04316176
#   0.27312614 -0.07672175 -0.22529898  0.1732629   0.48502219  0.1177899
#  -0.01337161 -0.25591023 -0.02420051  0.07512098 -0.23389238 -0.07017321
#   0.32482594  0.16852213 -0.03107152 -0.54188273  0.3720634  -0.01212865
#  -0.21112003 -0.25990166  0.12706249 -0.24139638  0.3289991  -0.06864262
#   0.04736702 -0.15215841 -0.08921262]

# %%
ML_matrices['d73297424']
# Out:
# array([[ 0.12181906,  0.04885376,  0.16584609, ...,  0.09591865,
#          0.04070074,  0.02890961],
#        [ 0.04885376,  0.49709684,  0.09132976, ...,  0.08017769,
#         -0.00527349,  0.01776184],
#        [ 0.16584609,  0.09132976,  0.65189424, ...,  0.28258685,
#          0.13578285, -0.0070648 ],
#        ...,
#        [ 0.09591865,  0.08017769,  0.28258685, ...,  0.85622325,
#          0.18294907,  0.0124648 ],
#        [ 0.04070074, -0.00527349,  0.13578285, ...,  0.18294907,
#          0.41324515, -0.00121364],
#        [ 0.02890961,  0.01776184, -0.0070648 , ...,  0.0124648 ,
#         -0.00121364,  0.26444795]])

# %%
 |nwm_cov = open('/home/diogro/Dropbox/labbio/cov_bayes_data/small.nwm.matrix.cov.bayes.csv', 'w')
nwm_means = open('/home/diogro/Dropbox/labbio/cov_bayes_data/small.nwm.matrix.means.bayes.csv', 'w')
nwm_names = open('/home/diogro/Dropbox/labbio/cov_bayes_data/small.nwm.names.txt', 'w')
for n in t.nodes(filter_fn=(is_named)):
    name = get_node_name(n)
    (bayes_matrices[str(n)]).tofile(nwm_cov, sep=';')
    (bayes_means[str(n)]).tofile(nwm_means, sep=';')
    nwm_cov.write('\n')
    nwm_means.write('\n')
    nwm_names.write(str(name).replace(' ', '_') + '\n')
nwm_names.flush()
nwm_cov.flush()
nwm_means.flush()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-5-07e95b0c53d5> in <module>()
# ----> 1 nwm_cov = open('/home/diogro/Dropbox/labbio/cov_bayes_data/small.nwm.matrix.cov.bayes.csv', 'w')
#       2 nwm_means = open('/home/diogro/Dropbox/labbio/cov_bayes_data/small.nwm.matrix.means.bayes.csv', 'w')
#       3 nwm_names = open('/home/diogro/Dropbox/labbio/cov_bayes_data/small.nwm.names.txt', 'w')
#       4 for n in t.nodes(filter_fn=(is_named)):
#       5     name = get_node_name(n)
#
# IOError: [Errno 2] No such file or directory: '/home/diogro/Dropbox/labbio/cov_bayes_data/small.nwm.matrix.cov.bayes.csv'

# %%
import monkey_model as m

# %%
m.t.print_plot()
# Out:
#                                       /----- Aotus azarai boliviensis
#                                  /----+
# /--------------------------------+    \----- Aotus nigriceps
# |                                |
# |                                \---------- Aotus lemurinus
# |
# |               /--------------------------- Callimico goeldii
# |               |
# |               |                     /----- Callithrix argentata
# |          /----+                /----+
# |          |    |     /----------+    \----- Callithrix humeralifera
# +          |    |     |          |
# |          |    \-----+          \---------- Callithrix pygmaea
# |          |          |
# |          |          |    /---------------- Callithrix geoffroyi
# |    /-----+          \----+
# |    |     |               |     /---------- Callithrix jacchus
# |    |     |               \-----+
# |    |     |                     |    /----- Callithrix kuhli
# |    |     |                     \----+
# \----+     |                          \----- Callithrix penicillata
#      |     |
#      |     \-------------------------------- Leontopithecus rosalia
#      |
#      |                                /----- Saguinus midas
#      |                           /----+
#      \---------------------------+    \----- Saguinus mystax
#                                  |
#                                  \---------- Saguinus fuscicollis
