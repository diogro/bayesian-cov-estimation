# %%
import os, sys, inspect
# realpath() with make your script run, even if you symlink it :)
cmd_folder = os.path.realpath(os.path.abspath(os.path.split(inspect.getfile( inspect.currentframe() ))[0]))
if cmd_folder not in sys.path:
    sys.path.insert(0, cmd_folder)

# use this if you want to include modules from a subforder
cmd_subfolder = os.path.realpath(os.path.abspath(os.path.join(os.path.split(inspect.getfile( inspect.currentframe() ))[0],"../models")))
if cmd_subfolder not in sys.path:
    sys.path.insert(0, cmd_subfolder)

cmd_subfolder = os.path.realpath(os.path.abspath(os.path.join(os.path.split(inspect.getfile( inspect.currentframe() ))[0],"../utils")))
if cmd_subfolder not in sys.path:
    sys.path.insert(0, cmd_subfolder)

# %%
import pymc as pm
import pandas as pd
import numpy as np
import dendropy
import monkey_model
import matrix_functions as mf

# %%
reload(monkey_model)
# Out:
# <module 'monkey_model' from '/home/diogro/projects/bayesian-cov-estimation/models/monkey_model.pyc'>

# %%
M = pm.MCMC(monkey_model, db='pickle', dbname='../pickles/NWM.genus.pickle')

# %%
M.sample(iter=10000, burn=9000, thin=10)
M.db.close()
# Out:
# [****************100%******************]  10000 of 10000 complete

# %%
x= [(k,v.trace[-1]) for k,v in M.var_factors.items() ]
sorted(x, key=lambda y: y[1])
# Out:
# [('Leontopithecus__rosalia', 3.2251354892927044e-05),
#  ('Callicebus__moloch', 0.00016878563739987088),
#  ('Callicebus__cupreus', 0.00028050019895768094),
#  ('Cacajao__calvus__ucayalii__F', 0.00052813084168101311),
#  ('Saguinus__inustus', 0.00067107064656235255),
#  ('Cebus__macrocephalu__macrocephalu__M', 0.00081966945055290854),
#  ('Cebus__macrocephalu', 0.00083566569805705007),
#  ('Callimico__goeldii__M', 0.0010403808968600398),
#  ('Callimico__goeldii__F', 0.0011096211990292179),
#  ('Leontopithecus__rosalia__MNRJ', 0.001282067682770017),
#  ('Lagothrix__lagothricha__lugens', 0.0017485870544715479),
#  ('Callicebus__donacophilus__pallescens', 0.001817703488070047),
#  ('Leontopithecus__rosalia__AMNH', 0.0020262383125106849),
#  ('Saimiri__macrodon', 0.0020338379133130607),
#  ('Aotus__nigriceps__nigriceps__M', 0.0022509518318333315),
#  ('Cebus__robustus__robustus__F', 0.0024938242929286665),
#  ('Cebus__libidinosus__libidinosus__F', 0.0028672561084092532),
#  ('Cebus__libidinosus', 0.0030393787305903678),
#  ('Saimiri__oerstedi__oerstedi__F', 0.003085064528728837),
#  ('Aotus__azarae__boliviensis', 0.003087258185675304),
#  ('Callicebus__brunneus__brunneus', 0.0032556440854035569),
#  ('Saimiri__ustus__ustus', 0.0036819641434974191),
#  ('Callicebus__brunneus__pop2__M', 0.0038264013780030456),
#  ('Callicebus__baptista__baptista__F', 0.0038681677840354941),
#  ('Ateles__geoffroyi__F', 0.0040216505766323789),
#  ('Aotus__vociferans__vociferans__F', 0.0040610727459019468),
#  ('Brachyteles__arachnoides__F', 0.0043071721855535488),
#  ('Ateles__paniscus__M', 0.0044461939743735534),
#  ('Saimiri__sciureus__sciureus__F', 0.0045943926416808388),
#  ('Leontopithecus__rosalia__USNM', 0.0048825257952435858),
#  ('Callicebus__hoffmannsi__hoffmannsi__M', 0.0050974902183933326),
#  ('Lagothrix__lagothricha__poeppigii__F', 0.0053453255206319019),
#  ('Pithecia__irrorata__irrorata__F', 0.071921557877871689),
#  ('Cebus__albifrons__cesarae__F', 0.073468550137681166),
#  ('Callicebus__torquatus__purinus__M', 0.075285337844369526),
#  ('Lagothrix__lagothricha__lugens__M', 0.075792757382862772),
#  ('Aotus__vociferans', 0.077753979060202594),
#  ('Aotus__nancymai', 0.077923877232903352),
#  ('Aotus__azarae__azarae__F', 0.078060487143498988),
#  ('Pithecia__pithecia', 0.078238128091428563),
#  ('Saguinus__fuscicollis__fuscus', 0.078828710232794044),
#  ('Callithrix__melanura', 0.078901236795825058),
#  ('Saimiri__ustus__ustus__M', 0.079586910765394758),
#  ('Cacajao__calvus__novaesi', 0.080301608511078953),
#  ('Aotus__brumbacki__brumbacki__M', 0.080859480502792874),
#  ('Cebus__libidinosus__versutus', 0.081278324583643508),
#  ('Aotus__azarae__boliviensis__F', 0.081671527303629171),
#  ('Callicebus__cupreus__cupreus__M', 0.082749493677998373),
#  ('Callicebus__donacophilus', 0.083632350344367057),
#  ('Ateles__chamek__F', 0.085883943064152465),
#  ('Saimiri__oerstedi__citrinellus', 0.087141520035335596),
#  ('Cacajao__melanocephal__ouakary__M', 0.087287542432044507),
#  ('Cebus__capucinus__capucinus__M', 0.088653176293288699),
#  ('Saguinus__bicolor', 0.089024689024293141),
#  ('Cebus__paraguayanus__paraguayanus__F', 0.090899711870888036),
#  ('Ateles__marginatus__F', 0.092439150861303596),
#  ('Lagothrix__lagothricha__lugens__F', 0.092443162015249325),
#  ('Callicebus__personatus__nigrifons__M', 0.092726608746050335),
#  ('Pithecia__irrorata__vanzolinii', 0.093215253344789195),
#  ('Cacajao__calvus__novaesi__M', 0.093573918493589148),
#  ('Ateles__chamek', 0.09501639078183563),
#  ('Callicebus__ornatus__ornatus__M', 0.096775473328245862),
#  ('Cebus__apella__apella__M', 0.099484139318557527),
#  ('Saimiri__oerstedi__oerstedi', 0.10187863252288598),
#  ('Callithrix__argentata', 0.10636377225444321),
#  ('Lagothrix__lagothricha__lagothricha__M', 0.1071867402271013),
#  ('Pithecia__monacha', 0.10801019254644259),
#  ('Saguinus__bicolor__bicolor', 0.11046302966195287),
#  ('Callicebus__donacophilus__pallescens__M', 0.11124347583053223),
#  ('Saimiri__vanzolinii', 0.11368918329251192),
#  ('Saguinus__bicolor__martinsi', 0.1141421353992841),
#  ('Callicebus__ornatus', 0.114971929143727),
#  ('Saguinus__labiatus', 0.11631974647083387),
#  ('Aotus__brumbacki__brumbacki__F', 0.11882242006368601),
#  ('Callicebus__baptista', 0.11899806470098573),
#  ('Callicebus__personatus', 0.11998502361320329),
#  ('Cebus__nigritus__vellerosus__M', 0.12126415087079287),
#  ('Lagothrix', 0.12218895687164982),
#  ('Saimiri__ustus__madeirae__F', 0.12222224423542404),
#  ('Ateles__paniscus__F', 0.12421194666164),
#  ('Saguinus__mystax', 0.12586693702994273),
#  ('Callicebus__discolor', 0.12607228789878697),
#  ('Chiropotes__albinasus__albinasus__M', 0.12690728886660366),
#  ('Callicebus__brunneus__pop2', 0.12694104216928959),
#  ('Cacajao__melanocephal__melanocephal__F', 0.12793876515412234),
#  ('Pithecia__albicans', 0.13075495752492844),
#  ('Lagothrix__lagothricha__lagothricha', 0.13187346399920244),
#  ('Ateles__marginatus', 0.13429289674933706),
#  ('Aotus__vociferans__vociferans__M', 0.13528159630346315),
#  ('Saimiri__boliviensis', 0.1370071987833642),
#  ('Pithecia__pithecia__pithecia', 0.1428358566103623),
#  ('Ateles__chamek__M', 0.14491856455296062),
#  ('Saguinus__imperator', 0.14726409819297887),
#  ('Saguinus__nigricollis__graellsi', 0.15303199445971241),
#  ('Pithecia__pithecia__chrysocephal', 0.15495566185338447),
#  ('Saguinus__bicolor__ochraceus', 0.15704158619453448),
#  ('Chiropotes__albinasus', 0.15706824478498968),
#  ('Saimiri__albigena', 0.15928842800521886),
#  ('Chiropotes__satanas__utahicki__M', 0.15961425477257707),
#  ('Saguinus__midas__midas', 0.16104867057016431),
#  ('Aotus__trivirgatus', 0.16528071620375728),
#  ('Callicebus__brunneus__brunneus__M', 0.16715023612681548),
#  ('Chiropotes__satanas__chiropotes', 0.17027539037259729),
#  ('Lagothrix__lagothricha', 0.17458277770362632),
#  ('Cacajao__melanocephal__melanocephal__M', 0.18798816875741958),
#  ('Callithrix__humeralifera__humeralifera', 0.19256692452414031),
#  ('Saguinus__fuscicollis__melanoleucus', 0.19558693549331299),
#  ('Saguinus__fuscicollis', 0.20396802968649752),
#  ('Cacajao__melanocephal__ouakary', 0.21001443258081193),
#  ('Alouatta__palliata__F', 0.21454285023883971),
#  ('Callicebus__torquatus', 0.21579736202193248),
#  ('Callicebus__torquatus__lugens', 0.21598886922672092),
#  ('Callithrix__RIO', 0.22168452988217971),
#  ('Callithrix__geoffroyi', 0.2224120393577281),
#  ('Saguinus__mystax__mystax', 0.22322069795419644),
#  ('Callithrix__chrysoleuca', 0.22464222444031673),
#  ('Callicebus__personatus__personatus', 0.22524613512343994),
#  ('Aotus__brumbacki', 0.22666029072461383),
#  ('Callicebus__torquatus__purinus', 0.22870713349263644),
#  ('Pithecia', 0.2426928229783365),
#  ('Callicebus__donacophilus__donacophilus__M', 0.24452644295335671),
#  ('Leontopithecus__chrysomelas', 0.24488153443401106),
#  ('Alouatta__belzebul__F', 0.24872922788700938),
#  ('Saimiri__sciureus', 0.26015688279548577),
#  ('Pithecia__irrorata', 0.26019357921779113),
#  ('Callicebus__personatus__nigrifons__F', 0.26514260803611278),
#  ('Saguinus__leucopus', 0.26885660042700299),
#  ('Callithrix__aurita', 0.26932932545063915),
#  ('Chiropotes', 0.27323097845362598),
#  ('Chiropotes__satanas', 0.28823547508758457),
#  ('Saguinus__midas', 0.29698671904284241),
#  ('Pithecia__albicans__albicans__M', 0.30474750372716453),
#  ('Saimiri', 0.31070195876124418),
#  ('Cebus__xanthosterno', 0.31167077368730528),
#  ('Alouatta__senicula', 0.31586825971534521),
#  ('Callithrix__penicillata', 0.33470960587692755),
#  ('Saguinus__fuscicollis__illigeri', 0.33482072228546056),
#  ('Alouatta', 0.3393209779613342),
#  ('Cebus__albifrons__albifrons__M', 0.35976867261338785),
#  ('Callithrix__kuhlii', 0.36956817330664249),
#  ('Cacajao', 0.38849489122991188),
#  ('Callithrix__jacchus', 0.3888880155392207),
#  ('Alouatta__fusca__M', 0.41173254542185267),
#  ('Pithecia__aequatoriali__aequatoriali__M', 0.42446936309606476),
#  ('Alouatta__fusca', 0.43122144392829875),
#  ('Alouatta__fusca__F', 0.48704617140727618),
#  ('Callithrix', 0.49856117310343429),
#  ('Alouatta__caraya', 0.58647927071303507),
#  ('Saguinus__oedipus', 0.61588928637466689),
#  ('Saguinus__geoffroyi', 0.65431764578604612),
#  ('Callicebus', 0.69809390144042882),
#  ('Alouatta__senicula__M', 0.86393489641344057),
#  ('Cebus__albifrons__cesarae', 0.9242910076851526),
#  ('Ateles', 0.92746217282148624),
#  ('Ateles__paniscus', 0.9475032075920613),
#  ('Lagothrix__flavicauda__flavicauda__M', 0.95002058583183158),
#  ('Alouatta__caraya__M', 0.99652747563193422),
#  ('Alouatta__belzebul__M', 1.0526864116938215),
#  ('Cebus__capucinus', 1.275911260541569),
#  ('Aotus', 1.3299221924491305),
#  ('23', 1.3896435805767815),
#  ('Cebus__nigrivitattu', 1.3953991586901489),
#  ('Ateles__geoffroyi', 1.4416938569165185),
#  ('Alouatta__villosa__F', 1.6512478545632148),
#  ('22', 1.9731634559984514),
#  ('Cebus', 2.322557243463891),
#  ('Alouatta__palliata', 2.3500803320149246),
#  ('Saguinus', 2.4235369517268244),
#  ('27', 2.7014903488724444),
#  ('29', 2.7678901748476479),
#  ('28', 4.3371156474552235),
#  ('Alouatta__villosa__M', 4.3376405268372302),
#  ('1', 5.0501951507812484),
#  ('2', 6.0620282158141396),
#  ('11', 6.1485270628585784),
#  ('30', 6.6475092937618854),
#  ('4', 7.1238845658773799),
#  ('26', 7.7357137957499464),
#  ('5', 9.8662953819300725),
#  ('18', 9.9133539265506361),
#  ('9', 10.351298528609723),
#  ('14', 10.944481316968478),
#  ('25', 11.126766231891953),
#  ('24', 12.487639938992675),
#  ('6', 14.447860862632769),
#  ('16', 14.938934501984827),
#  ('12', 15.51337639089644),
#  ('10', 15.857675814066701),
#  ('13', 16.300932532665236),
#  ('3', 17.789897132113019),
#  ('20', 19.831337298356036),
#  ('8', 21.528322975335165),
#  ('21', 22.25283121535346),
#  ('19', 22.929803103246961),
#  ('7', 26.395286550867716),
#  ('17', 26.5386927676151),
#  ('15', 50.59454560219644)]

# %%
pop_size = 100
pops = {}

for species in monkey_model.data_list:
    species_name = str(species).replace('data_', '')

    thetas = M.get_node('theta_{}'.format(species_name)).trace()
    sigmas = M.get_node('sigma_{}'.format(species_name)).trace()
    
    params = zip(thetas, sigmas)
        
    pops[species_name] = []
    for p in params:

        pops[species_name].append(np.random.multivariate_normal(p[0], p[1], pop_size))
        
    pops[species_name] = np.array(pops[species_name])

# %%
stats = {}

for species in monkey_model.data_list:
    species_name = str(species).replace('data_', '')
    stats[species_name] = {}
    stats[species_name]['mean'] = np.array([r.mean(0) for r in pops[species_name]])
    stats[species_name]['var'] = np.array([r.var(0) for r in pops[species_name]])
    stats[species_name]['min'] = np.array([r.min(0) for r in pops[species_name]])
    stats[species_name]['max'] = np.array([r.max(0) for r in pops[species_name]])

# %%
plot_mean_hists('Callicebus__torquatus__purinus__M', stats, 2)

# %%
from matplotlib.pyplot import *

def plot_mean_hists(species, stats, r):
    pop_m = stats[species]['mean']

    for ti in xrange(0, pop_m.shape[1]):
        figure(r*pop_m.shape[1] + ti)
        hist(pop_m[:,ti])
        orig_m = M.get_node('data_' + species).value.mean(0)[ti]
        axvline(orig_m, color='r', linestyle='dashed', linewidth=2)    
        xlabel(species)
        
def plot_mean(species, stats, r):
    pop_m = stats[species]['mean']

    for ti in xrange(0, pop_m.shape[1]):
        figure(r*pop_m.shape[1] + ti)
        plot(pop_m[:,ti])
        orig_m = M.get_node('data_' + species).value.mean(0)[ti]
        axhline(orig_m, color='r', linestyle='dashed', linewidth=2)
        
def plot_size(species, stats, r):
    pop_m = stats[species]['mean']

    for ti in xrange(0, pop_m.shape[1]):
        figure(r*pop_m.shape[1] + ti)
        plot(pop_m[:,ti])
        orig_m = len(M.get_node('data_' + species).value)
        axhline(orig_m, color='r', linestyle='dashed', linewidth=2)

# %%
root = monkey_model.t.seed_node
tree_idx = {str(root): 0}
bayes_means = {str(root): M.theta[tree_idx[str(root)]].trace[:].mean(0)}
bayes_matrices = {str(root): M.sigma[tree_idx[str(root)]].trace[:].mean(0)}
ML_matrices = monkey_model.node_matrices
ML_means = monkey_model.node_means

NWM_matrices = mf.read_matrices("../matrices/nwm.matrices.csv", "../matrices/nwm.matrices.labels.txt", 39)

i = 1
for n in monkey_model.t.nodes()[1:]:
    tree_idx[str(n)] = i
    bayes_means[str(n)] = M.theta[tree_idx[str(n)]].trace[:].mean(0)
    bayes_matrices[str(n)] = M.sigma[tree_idx[str(n)]].trace[:].mean(0)
    i = i + 1

is_named = lambda node: ((node.taxon is not None) or (node.label is not None))

get_node_name = lambda n: n.label or n.taxon or None

for i, n in enumerate(monkey_model.t.nodes(filter_fn=(is_named))):
    name = get_node_name(n)
    figure(i)
    #print str(name), str(n), monkey_model.node_sample_size[str(n)]
    
    print name, "RS = ", mf.random_skewers(ML_matrices[str(n)], bayes_matrices[str(n)])   
    
    ML_val, ML_vec = np.linalg.eig(ML_matrices[str(n)])
    bayes_val, bayes_vec = np.linalg.eig(bayes_matrices[str(n)])     
                          
    ML_val.sort()
    bayes_val.sort()
    
    plot(ML_val[:-15], label='ML')
    plot(bayes_val[:-15], label='Bayes')
    legend()
    title(name)
    sort
    #print ML_means[str(n)] - bayes_means[str(n)]
# Out:
# Cacajao RS =  0.999630513013
# Chiropotes
#  RS =  0.998595577448
# Pithecia
#  RS =  0.999306850311
# Callicebus
#  RS =  0.998790795592
# Callimico
#  RS =  0.999999999288
# Callithrix
#  RS =  0.999638198985
# Cebuella
#  RS =  0.985485814582
# Leontopithecus
#  RS =  0.999981933868
# Saguinus
#  RS =  0.994657466787
# Cebus
#  RS =  0.999705059843
# Saimiri
#  RS =  0.999607727942
# Aotus
#  RS =  0.998808571366
# Lagothrix
#  RS =  0.999631918089
# Brachyteles
#  RS =  0.999997279773
# Ateles
#  RS =  0.998998450294
# Alouatta
#  RS =  0.998966926562

# %%
nwm_cov = open('/home/diogro/Dropbox/labbio/cov_bayes_data/small.nwm.matrix.cov.bayes.csv', 'w')
nwm_means = open('/home/diogro/Dropbox/labbio/cov_bayes_data/small.nwm.matrix.means.bayes.csv', 'w')
nwm_names = open('/home/diogro/Dropbox/labbio/cov_bayes_data/small.nwm.names.txt', 'w')
for n in monkey_model.t.nodes(filter_fn=(is_named)):
    name = get_node_name(n)
    (bayes_matrices[str(n)]).tofile(nwm_cov, sep=';')
    (bayes_means[str(n)]).tofile(nwm_means, sep=';')
    nwm_cov.write('\n')
    nwm_means.write('\n')
    nwm_names.write(str(name).replace(' ', '_') + '\n')
nwm_names.flush()
nwm_cov.flush()
nwm_means.flush()

# %%
x = range(10)

# %%
x.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-121-7e0c547c09ec> in <module>()
# ----> 1 typeof(x)
#
# NameError: name 'typeof' is not defined

# %%
x = np.random.rand(10)

# %%
x.sort()

# %%
x
# Out:
# array([ 0.14614053,  0.28849187,  0.35694071,  0.61626219,  0.81789323,
#         0.82762183,  0.94354907,  0.98930251,  0.99021477,  0.99132942])
