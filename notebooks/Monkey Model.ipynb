# %%
import os, sys, inspect
# realpath() with make your script run, even if you symlink it :)
cmd_folder = os.path.realpath(os.path.abspath(os.path.split(inspect.getfile( inspect.currentframe() ))[0]))
if cmd_folder not in sys.path:
    sys.path.insert(0, cmd_folder)

# use this if you want to include modules from a subforder
cmd_subfolder = os.path.realpath(os.path.abspath(os.path.join(os.path.split(inspect.getfile( inspect.currentframe() ))[0],"../models")))
if cmd_subfolder not in sys.path:
    sys.path.insert(0, cmd_subfolder)

cmd_subfolder = os.path.realpath(os.path.abspath(os.path.join(os.path.split(inspect.getfile( inspect.currentframe() ))[0],"../utils")))
if cmd_subfolder not in sys.path:
    sys.path.insert(0, cmd_subfolder)

# %%
import pymc as pm
import pandas as pd
import numpy as np
import dendropy
import monkey_model
import matrix_functions as mf

# %%
reload(monkey_model)
# Out:
# <module 'monkey_model' from '/home/diogro/projects/bayesian-cov-estimation/models/monkey_model.pyc'>

# %%
M = pm.MCMC(monkey_model, db='pickle', dbname='../pickles/NWM.genus.pickle')

# %%
M.sample(iter=500, burn=400, thin=1)
M.db.close()
# Out:
# [                  0%                  ]

# %%
x= [(k,v.trace[-1]) for k,v in M.var_factors.items() ]
sorted(x, key=lambda y: y[1])
# Out:
# [('Saimiri', 1.3374735288880217e-07),
#  ('Cacajao__melanocephal', 0.0026996495345698287),
#  ('Alouatta', 0.0049757106863614949),
#  ('Saimiri__macrodon', 0.0061447936004112884),
#  ('Callicebus__moloch', 0.0094093465459405383),
#  ('Leontopithecus', 0.0097726216376255517),
#  ('Ateles__marginatus', 0.020684244956777249),
#  ('Callithrix__penicillata', 0.026044490965135118),
#  ('Lagothrix', 0.02967114916502283),
#  ('Callicebus__hoffmannsi', 0.034025842662105947),
#  ('Callithrix__emiliae', 0.034598129354783541),
#  ('Callicebus__cinerascens', 0.034644172014755309),
#  ('Callithrix__RIO', 0.036862048080737619),
#  ('Cebus__macrocephalu', 0.040362878536025597),
#  ('Cebus__paraguayanus', 0.042145928510664885),
#  ('Aotus', 0.043168827633999651),
#  ('Saguinus', 0.043462191748915482),
#  ('Cebus__apella', 0.044077308159373253),
#  ('Pithecia__aequatoriali', 0.045639952985569811),
#  ('Cacajao', 0.05080244918557246),
#  ('Saimiri__sciureus', 0.051045408070210581),
#  ('Aotus__nancymai', 0.05117489020248478),
#  ('Aotus__infulatus', 0.056345637689255712),
#  ('Cebus__nigritus', 0.058386480740028696),
#  ('Leontopithecus__rosalia', 0.060187967223650496),
#  ('Pithecia__monacha', 0.061124242003069096),
#  ('Saguinus__imperator', 0.063005226689334545),
#  ('Callithrix__aurita', 0.064496479844388471),
#  ('Lagothrix__lagothricha', 0.067219023494628299),
#  ('Callithrix__melanura', 0.069544256871548152),
#  ('Saimiri__cassiquiaren', 0.069591603113769857),
#  ('Cebus__libidinosus', 0.070411451634587188),
#  ('Saimiri__oerstedi', 0.070844393296387267),
#  ('Saguinus__bicolor', 0.073061485978749369),
#  ('Callithrix__argentata', 0.074673180138735751),
#  ('Callithrix__geoffroyi', 0.076923832444291185),
#  ('Callithrix__humeralifera', 0.082514288128005431),
#  ('Saguinus__tripartitus', 0.095499428480823545),
#  ('Cebus__robustus', 0.10132850133079967),
#  ('Saimiri__albigena', 0.10497408477209402),
#  ('Aotus__lemurinus', 0.10594781094023956),
#  ('Callithrix__chrysoleuca', 0.10716297060251317),
#  ('Callicebus__ornatus', 0.10731396235787982),
#  ('Chiropotes', 0.11169351567815064),
#  ('Saimiri__boliviensis', 0.11537910333906452),
#  ('Saguinus__nigricollis', 0.11792881734499401),
#  ('Callithrix__kuhlii', 0.12434386946118138),
#  ('Saguinus__inustus', 0.12599061490261243),
#  ('Callicebus__brunneus', 0.12731461301012098),
#  ('Aotus__vociferans', 0.13075481623887544),
#  ('Chiropotes__albinasus', 0.13891218525465804),
#  ('Callithrix', 0.14124295795213951),
#  ('Pithecia', 0.1416217517742161),
#  ('Aotus__nigriceps', 0.14420534309978783),
#  ('Saguinus__labiatus', 0.14531175253670739),
#  ('Callithrix__jacchus', 0.14556315193503117),
#  ('Saguinus__midas', 0.15039557336740289),
#  ('Saguinus__fuscicollis', 0.16328088441472718),
#  ('Callicebus__discolor', 0.1645154703347122),
#  ('Chiropotes__satanas', 0.17069459934881576),
#  ('Callicebus__donacophilus', 0.17185203037841795),
#  ('Cebus__xanthosterno', 0.18753119551722397),
#  ('Pithecia__albicans', 0.19488189136174261),
#  ('Callicebus__cupreus', 0.19721048509740599),
#  ('Cacajao__calvus', 0.19954600447624665),
#  ('Saimiri__vanzolinii', 0.20436740043961643),
#  ('Pithecia__pithecia', 0.20609340132494858),
#  ('Pithecia__irrorata', 0.21069579963928539),
#  ('Alouatta__belzebul', 0.21618700860055046),
#  ('Saimiri__ustus', 0.22778980759635001),
#  ('Callicebus__baptista', 0.23253993384347041),
#  ('Saguinus__mystax', 0.23406238497619533),
#  ('Saguinus__leucopus', 0.23480456883722983),
#  ('Aotus__brumbacki', 0.23734113437175808),
#  ('Alouatta__fusca', 0.23823702716267164),
#  ('Leontopithecus__chrysomelas', 0.26542307173341473),
#  ('Aotus__trivirgatus', 0.26963005002035406),
#  ('Ateles', 0.27356287803973378),
#  ('Saguinus__oedipus', 0.30419396214412142),
#  ('Callithrix__leucippe', 0.31516017070622976),
#  ('27', 0.32156696610994551),
#  ('Aotus__azarae', 0.32584617635678254),
#  ('Ateles__chamek', 0.35593315002874731),
#  ('Callicebus__torquatus', 0.35861450151585261),
#  ('Alouatta__senicula', 0.36363312034348216),
#  ('Callicebus', 0.39132929812858286),
#  ('Alouatta__caraya', 0.39740000397600539),
#  ('Ateles__geoffroyi', 0.39834161601932472),
#  ('Cebus', 0.40187822730920419),
#  ('4', 0.42796548056633188),
#  ('Cebus__albifrons', 0.43797124998119841),
#  ('11', 0.46279415778765104),
#  ('24', 0.48869593585073973),
#  ('Callicebus__personatus', 0.49104094848848406),
#  ('5', 0.56796877454388572),
#  ('Saguinus__geoffroyi', 0.57731673584416221),
#  ('16', 0.61859191873171326),
#  ('Ateles__paniscus', 0.66155626742542051),
#  ('25', 0.69359515509545522),
#  ('Lagothrix__flavicauda', 0.74844169052641096),
#  ('12', 0.83006893698111506),
#  ('Cebus__nigrivitattu', 1.0040470227638734),
#  ('Alouatta__palliata', 1.0853465809729126),
#  ('6', 1.1177233822154735),
#  ('Cebus__capucinus', 1.1311057328401055),
#  ('15', 1.3296804106141407),
#  ('Alouatta__villosa', 1.5185109834940071),
#  ('26', 1.9159036676382364),
#  ('13', 1.9711276805201459),
#  ('28', 1.9752970077246486),
#  ('2', 2.0534962826711816),
#  ('21', 2.194739478220455),
#  ('23', 2.3526598995491588),
#  ('14', 2.5880736119807284),
#  ('7', 2.6519734754049233),
#  ('10', 2.9077282000155797),
#  ('18', 3.1816061733028445),
#  ('9', 3.3610886026277673),
#  ('17', 3.6185358364252842),
#  ('3', 4.3203280649188924),
#  ('20', 5.0687769523383501),
#  ('19', 7.2492383699280598),
#  ('22', 13.573551681894568),
#  ('1', 14.837137147715199),
#  ('8', 17.475569891453716)]

# %%
pop_size = 100
pops = {}

for species in monkey_model.data_list:
    species_name = str(species).replace('data_', '')
    print species_name
    #thetas = M.get_node('theta_{}'.format(species_name)).trace()
    #sigmas = M.get_node('sigma_{}'.format(species_name)).trace()
    
    params = zip(thetas, sigmas)
        
    pops[species_name] = []
    for p in params:

        pops[species_name].append(np.random.multivariate_normal(p[0], p[1], pop_size))
        
    pops[species_name] = np.array(pops[species_name])
# Out:
# Cacajao__melanocephal
# Cacajao__calvus
# Chiropotes__satanas
# Chiropotes__albinasus
# Pithecia__aequatoriali
# Pithecia__pithecia
# Pithecia__monacha
# Pithecia__albicans
# Pithecia__irrorata
# Callicebus__moloch
# Callicebus__donacophilus
# Callicebus__baptista
# Callicebus__cinerascens
# Callicebus__ornatus
# Callicebus__cupreus
# Callicebus__personatus
# Callicebus__discolor
# Callicebus__torquatus
# Callicebus__hoffmannsi
# Callicebus__brunneus
# Callimico__goeldii
# Callithrix__jacchus
# Callithrix__chrysoleuca
# Callithrix__leucippe
# Callithrix__argentata
# Callithrix__humeralifera
# Callithrix__melanura
# Callithrix__RIO
# Callithrix__geoffroyi
# Callithrix__kuhlii
# Callithrix__aurita
# Callithrix__emiliae
# Callithrix__penicillata
# Leontopithecus__rosalia
# Leontopithecus__chrysomelas
# Saguinus__leucopus
# Saguinus__tripartitus
# Saguinus__imperator
# Saguinus__labiatus
# Saguinus__bicolor
# Saguinus__inustus
# Saguinus__fuscicollis
# Saguinus__nigricollis
# Saguinus__geoffroyi
# Saguinus__midas
# Saguinus__oedipus
# Saguinus__mystax
# Cebus__nigritus
# Cebus__libidinosus
# Cebus__apella
# Cebus__macrocephalu
# Cebus__nigrivitattu
# Cebus__xanthosterno
# Cebus__robustus
# Cebus__albifrons
# Cebus__capucinus
# Cebus__paraguayanus
# Saimiri__boliviensis
# Saimiri__cassiquiaren
# Saimiri__macrodon
# Saimiri__albigena
# Saimiri__oerstedi
# Saimiri__ustus
# Saimiri__vanzolinii
# Saimiri__sciureus
# Aotus__brumbacki
# Aotus__lemurinus
# Aotus__nancymai
# Aotus__nigriceps
# Aotus__azarae
# Aotus__trivirgatus
# Aotus__vociferans
# Aotus__infulatus
# Lagothrix__lagothricha
# Lagothrix__flavicauda
# Brachyteles__arachnoides
# Ateles__chamek
# Ateles__marginatus
# Ateles__paniscus
# Ateles__geoffroyi
# Alouatta__palliata
# Alouatta__caraya
# Alouatta__villosa
# Alouatta__belzebul
# Alouatta__senicula
# Alouatta__fusca

# %%
str(monkey_model.t.find_node_with_taxon_label("Callimico"))
# Out:
# 'd97704464'

# %%
stats = {}

for species in monkey_model.data_list:
    species_name = str(species).replace('data_', '')
    print species_name
    stats[species_name] = {}
    stats[species_name]['mean'] = np.array([r.mean(0) for r in pops[species_name]])
    stats[species_name]['var'] = np.array([r.var(0) for r in pops[species_name]])
    stats[species_name]['min'] = np.array([r.min(0) for r in pops[species_name]])
    stats[species_name]['max'] = np.array([r.max(0) for r in pops[species_name]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-bd25796034f1> in <module>()
#       1 stats = {}
#       2
# ----> 3 for species in monkey_model.data_list:
#       4     species_name = str(species).replace('data_', '')
#       5     print species_name
#
# NameError: name 'monkey_model' is not defined

# %%
plot_mean_hists('Saguinus_midas__midas_niger__M', stats, 2)

# %%
from matplotlib.pyplot import *

def plot_mean_hists(species, stats, r):
    pop_m = stats[species]['mean']

    for ti in xrange(0, pop_m.shape[1]):
        figure(r*pop_m.shape[1] + ti)
        hist(pop_m[:,ti])
        orig_m = M.get_node('data_' + species).value.mean(0)[ti]
        axvline(orig_m, color='r', linestyle='dashed', linewidth=2)    
        xlabel(species)
        
def plot_mean(species, stats, r):
    pop_m = stats[species]['mean']

    for ti in xrange(0, pop_m.shape[1]):
        figure(r*pop_m.shape[1] + ti)
        plot(pop_m[:,ti])
        orig_m = M.get_node('data_' + species).value.mean(0)[ti]
        axhline(orig_m, color='r', linestyle='dashed', linewidth=2)
        
def plot_size(species, stats, r):
    pop_m = stats[species]['mean']

    for ti in xrange(0, pop_m.shape[1]):
        figure(r*pop_m.shape[1] + ti)
        plot(pop_m[:,ti])
        orig_m = len(M.get_node('data_' + species).value)
        axhline(orig_m, color='r', linestyle='dashed', linewidth=2)

# %%
len(M.get_node('data_' + 'Saguinus_midas__midas_niger__M').value)
# Out:
# 10

# %%
root = monkey_model.t.seed_node
tree_idx = {str(root): 0}
bayes_means = {str(root): M.theta[tree_idx[str(root)]].trace[:].mean(0)}
bayes_matrices = {str(root): M.sigma[tree_idx[str(root)]].trace[:].mean(0)}
ML_matrices = monkey_model.node_matrices
ML_means = monkey_model.node_means

NWM_matrices = mf.read_matrices("../matrices/nwm.matrices.csv", "../matrices/nwm.matrices.labels.txt", 39)

i = 1
for n in monkey_model.t.nodes()[1:]:
    tree_idx[str(n)] = i
    bayes_means[str(n)] = M.theta[tree_idx[str(n)]].trace[:].mean(0)
    bayes_matrices[str(n)] = M.sigma[tree_idx[str(n)]].trace[:].mean(0)
    i = i + 1

is_named = lambda node: ((node.taxon is not None) or (node.label is not None))

get_node_name = lambda n: n.label or n.taxon or None

for n in monkey_model.t.nodes(filter_fn=(is_named)):
    name = get_node_name(n)
    
    print str(name), str(n), monkey_model.node_sample_size[str(n)]
    
    print "RS = ", mf.random_skewers(ML_matrices[str(n)], bayes_matrices[str(n)])                                              
    #print ML_means[str(n)] - bayes_means[str(n)]
# Out:
#  Cacajao d87827664 79
# RS =  0.999537473508
# Chiropotes d81658896 154
# RS =
# 0.998998272535
# Pithecia d81658384 231
# RS =  0.999290782859
# Callicebus d81661200 390
# RS =
# 0.999398194012
# Callimico d81660048 27
# RS =  1.0
# Callithrix d81661648 505
# RS =
# 0.999645492532
# Leontopithecus d81660752 45
# RS =  0.999991359991
# Saguinus d81658832 1135
# RS =
# 0.996967518164
# Cebus d81658064 394
# RS =  0.999695746495
# Saimiri d81661456 263
# RS =
# 0.999231970773
# Aotus d81661520 181
# RS =  0.998938809502
# Lagothrix d81661328 92
# RS =
# 0.999648951371
# Brachyteles d81661840 40
# RS =  0.999999818881
# Ateles d77436880 387
# RS =
# 0.999654506567
# Alouatta d77436496 387
# RS =  0.999599845596

# %%
nwm_cov = open('/home/diogro/Dropbox/labbio/cov_bayes_data/small.nwm.matrix.cov.bayes.csv', 'w')
nwm_means = open('/home/diogro/Dropbox/labbio/cov_bayes_data/small.nwm.matrix.means.bayes.csv', 'w')
nwm_names = open('/home/diogro/Dropbox/labbio/cov_bayes_data/small.nwm.names.txt', 'w')
for n in monkey_model.t.nodes(filter_fn=(is_named)):
    name = get_node_name(n)
    (bayes_matrices[str(n)]).tofile(nwm_cov, sep=';')
    (bayes_means[str(n)]).tofile(nwm_means, sep=';')
    nwm_cov.write('\n')
    nwm_means.write('\n')
    nwm_names.write(str(name).replace(' ', '_') + '\n')
nwm_names.flush()
nwm_cov.flush()
nwm_means.flush()
